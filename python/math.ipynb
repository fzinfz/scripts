# %% [markdown]
# # Bitwise Operators
# https://wiki.python.org/moin/BitwiseOperators

# %%
bin2list = lambda n: list(bin(n))[2:]
bin2list(503)
# Out:
# ['1', '1', '1', '1', '1', '0', '1', '1', '1']

# %%
int('0b11',2)
# Out:
# 3

# %%
bin(1<<3)
# Out:
# '0b1000'

# %%
bin( 503 | 1<<3 )
# Out:
# '0b111111111'

# %%
bin( ~(1<<6) ) # -65 ; complement | 二补数 | 二补码 | 补码  ; https://zh.wikipedia.org/wiki/%E4%BA%8C%E8%A3%9C%E6%95%B8
# Out:
# '-0b1000001'

# %%
bin( 0b111111110 & ~(1<<6) )
# Out:
# '0b110111110'

# %% [markdown]
# # Decimal
# https://docs.python.org/3/library/decimal.html

# %%
5//2
# Out:
# 2

# %%
import math
print(math.ceil(10.0))
print(math.ceil(10.1))
print(type(math.ceil(10.1)))
# Out:
# 10
# 11
# <class 'int'>

# %%
float('Inf')
# Out:
# inf

# %%
inf
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-6694b1596962> in <module>()
# ----> 1 inf
#
# NameError: name 'inf' is not defined

# %%
type(float('Inf'))
# Out:
# float

# %%
try:
    result = 1 / float('Inf')
except ZeroDivisionError:
    print('Infinite result')
else:
    print('Finite result: ', result)
# Out:
# Finite result:  0.0

# %%
# %matplotlib inline
import matplotlib
matplotlib.use('Agg')

# %%
#Current Transformer
import math
i_rms_current = 60
nb_turns = 2000
U_sensor = 1
I_measured = math.sqrt(2) * i_rms_current
I_sensor = I_measured / nb_turns 
print(I_sensor)
R_burden = U_sensor / I_sensor
print(R_burden)
P = I_sensor * I_sensor * R_burden
print(P)
# Out:
# 0.042426406871192854
# 23.57022603955158
# 0.042426406871192854

# %% [markdown]
# # AVG

# %%
avg = 2/math.pi
print(avg)
rms = 1/math.sqrt(2)
print(rms)
print(avg/rms)
print(avg/rms*220)
print(220/rms)
# Out:
# 0.6366197723675814
# 0.7071067811865475
# 0.9003163161571062
# 198.06958955456335
# 311.1269837220809

# %%
from numpy import *
import matplotlib.pyplot as plt
x = arange(0.,2 * pi,0.001)
y = sin(x)
y2 = abs(sin(x))
plt.plot(x,y)
plt.plot(x,y2)
plt.show()
sqrt(mean(square(y))) == sqrt(mean(square(y2))) # True
sqrt(mean(square(y2)))
# Out:
# 0.70706094306489775

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
ax.plot(range(3))
#fig.savefig('temp.png')
fig.show()
# Out:
# /home/ec2-user/anaconda3/lib/python3.4/site-packages/matplotlib/figure.py:387: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "

# %%
import numpy as np
def f(z,t):
    return np.exp(-z)*np.sin(t-z)

z = np.linspace(0,5,100)
t = np.arange(0,40000,4000)

for tval in t:
    plt.plot(z, f(z, tval))
plt.show()
t
len(z)
# Out:
# 100
